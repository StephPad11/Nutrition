# %% [markdown]
# **GOALS:**
#
# This notebook contains a dataset from Aleksandr Antonov on Kaggle, that includes the nutritional information of
# various common household products.  The hope is to make a classifier that can sort products into basic groupings; fruits,
# vegetables, grains, dairy, processed foods, based on their nutritional information while also providing a simple toolset
# for individuals or restaurants determine the nutritional value of their meals or menu items.
#
# **DATA:**
#
# Data is downloaded from Kaggle:
#     https://www.kaggle.com/datasets/trolukovich/nutritional-values-for-common-foods-and-products

# %% [markdown]
# **LOADING THE DATA:**
#
# Some immediate insights:
# - There are 77 unique columns and 8789 rows of products
#
# - The majority of columns are dtype "object" which isn't the greatest
# - Values include units which will be best added to the headers to allow for mathematical operations
# - There are plenty of columns that include vitamins or minerals the average person won't know or understand 'cryptoxanthin_beta' or 'isoleucine'
# - The column for zinc is spell zink which isn't incorrect but I will switch the spelling for my own clarity; iron is also misspelled as irom.
# - The only column with missing data (NaN values) appears to be saturated fats.

# %%
import pandas as pd
import numpy as np

nutrition = pd.read_csv('nutrition.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('max_info_columns', 100) 

nutrition.head()
# Out:
#    Unnamed: 0             name serving_size  calories total_fat saturated_fat cholesterol    sodium  choline     folate folic_acid    niacin pantothenic_acid riboflavin   thiamin vitamin_a vitamin_a_rae carotene_alpha carotene_beta cryptoxanthin_beta lutein_zeaxanthin  lucopene vitamin_b12 vitamin_b6 vitamin_c vitamin_d vitamin_e tocopherol_alpha vitamin_k    calcium    copper     irom  magnesium manganese phosphorous  potassium selenium     zink  protein  alanine arginine aspartic_acid  cystine glutamic_acid  glycine histidine hydroxyproline isoleucine  leucine   lysine methionine phenylalanine  proline   serine threonine tryptophan tyrosine   valine carbohydrate  fiber   sugars fructose galactose glucose lactose maltose sucrose      fat saturated_fatty_acids monounsaturated_fatty_acids polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# ...

# %%
#nutrition.columns
print(nutrition.dtypes.to_string())
# Out:
# Unnamed: 0                      int64
# name                           object
# serving_size                   object
# calories                        int64
# total_fat                      object
# saturated_fat                  object
# cholesterol                    object
# sodium                         object
# choline                        object
# folate                         object
# folic_acid                     object
# niacin                         object
# pantothenic_acid               object
# riboflavin                     object
# thiamin                        object
# vitamin_a                      object
# vitamin_a_rae                  object
# carotene_alpha                 object
# carotene_beta                  object
# cryptoxanthin_beta             object
# lutein_zeaxanthin              object
# lucopene                        int64
# vitamin_b12                    object
# vitamin_b6                     object
# vitamin_c                      object
# ...

# %%
nutrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 77 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   8789 non-null   int64
#  1   name                         8789 non-null   object
#  2   serving_size                 8789 non-null   object
#  3   calories                     8789 non-null   int64
#  4   total_fat                    8789 non-null   object
#  5   saturated_fat                7199 non-null   object
#  6   cholesterol                  8789 non-null   object
#  7   sodium                       8789 non-null   object
#  8   choline                      8789 non-null   object
#  9   folate                       8789 non-null   object
#  10  folic_acid                   8789 non-null   object
#  11  niacin                       8789 non-null   object
#  12  pantothenic_acid             8789 non-null   object
# ...

# %% [markdown]
# **SATURATED FAT NAN VALUES:**
#
# saturated_fat is the only column with NaN values, and at first glance they appear to be products with very low total
# fat count.  While it maybe easy to replace the saturated NaN value with a 0, there are outliers like Pan Dulce at index 8772 so further exploration is needed.

# %%
# Printing out saturated_fat NaN values

nan_SF = nutrition[nutrition['saturated_fat'].isna()]
#print(nan_SF)

# Commenting out the print statement because it will be nearly illegible outside of the workspace.
# Out:
#       Unnamed: 0                                               name serving_size  calories total_fat saturated_fat cholesterol     sodium choline     folate folic_acid    niacin pantothenic_acid riboflavin   thiamin    vitamin_a vitamin_a_rae carotene_alpha carotene_beta cryptoxanthin_beta lutein_zeaxanthin  lucopene vitamin_b12 vitamin_b6 vitamin_c vitamin_d vitamin_e tocopherol_alpha vitamin_k    calcium    copper     irom magnesium manganese phosphorous  potassium selenium     zink  protein  alanine arginine aspartic_acid  cystine glutamic_acid  glycine histidine hydroxyproline isoleucine  leucine   lysine methionine phenylalanine  proline   serine threonine tryptophan tyrosine   valine carbohydrate   fiber   sugars fructose galactose glucose lactose maltose  sucrose      fat saturated_fatty_acids monounsaturated_fatty_acids polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# ...

# %% [markdown]
# **DATA CLEANING:**
#
# As mentioned above there are 77 unique features of this dataset and for the majority of people 85% of them will be
# unneccesary.  Copying and limiting the dataset to 12 features will ensure the integrity of the original set while providing the most useful results for our purposes.
#
# Included columns are:
#
#     'name', 'serving_size', 'calories', 'total_fat', 'saturated_fat', 'cholesterol', 'sodium', 'sugars', 'carbohydrate', 'fiber', 'alcohol', 'caffeine'

# %%
nutrition_filtered = nutrition[['name', 'serving_size', 'calories', 'total_fat', 'saturated_fat', 'cholesterol', 'sodium', 
                               'sugars', 'carbohydrate', 'fiber', 'alcohol', 'caffeine']]
print(nutrition_filtered.head())
# Out:
#               name serving_size  calories total_fat saturated_fat cholesterol    sodium   sugars carbohydrate  fiber alcohol caffeine
# 0       Cornstarch        100 g       381      0.1g           NaN           0   9.00 mg   0.00 g      91.27 g  0.9 g   0.0 g  0.00 mg
# 1     Nuts, pecans        100 g       691       72g          6.2g           0   0.00 mg   3.97 g      13.86 g  9.6 g   0.0 g  0.00 mg
# 2    Eggplant, raw        100 g        25      0.2g           NaN           0   2.00 mg   3.53 g       5.88 g  3.0 g   0.0 g  0.00 mg
# 3   Teff, uncooked        100 g       367      2.4g          0.4g           0  12.00 mg   1.84 g      73.13 g  8.0 g       0        0
# 4  Sherbet, orange        100 g       144        2g          1.2g         1mg  46.00 mg  24.32 g      30.40 g  1.3 g   0.0 g  0.00 mg

# %% [markdown]
# **CLEANING THE UNITS:**
#
# Each feature after name has additional units applied to each value.  The units are useful but make using the data in numerical operations impossible.  Moving the units to the column name will keep the information but make the data more useable.

# %%
# First we need to go column by column and ensure the units are uniform for each column.  If the serving size for
# 'apple' is in 'ea' for each that'll throw off any stripping we do.

# all_grams_n where n is the index of the column name

# serving_size
all_grams_2 = nutrition_filtered['serving_size'].str.match(r'^\d+(\.\d+)?\s*g$').all()
print(all_grams_2) #True

# total_fat
all_grams_4 = nutrition_filtered['total_fat'].str.match(r'^\d+(\.\d+)?\s*g$').all()
print(all_grams_4) #True

# saturated_fat
#all_grams_5 = nutrition_filtered['saturated_fat'].str.match(r'^\d+(\.\d+)?\s*g$').all()
#print(all_grams_5)

# sodium
all_grams_7 = nutrition_filtered['sodium'].str.match(r'^\d+(\.\d+)?\s*g$').all()
print(all_grams_7) #False

# sugars
all_grams_8 = nutrition_filtered['sugars'].str.match(r'^\d+(\.\d+)?\s*g$').all()
print(all_grams_8) #True

# carbohydrate
all_grams_9 = nutrition_filtered['carbohydrate'].str.match(r'^\d+(\.\d+)?\s*g$').all()
print(all_grams_9) #True

# fiber
all_grams_10 = nutrition_filtered['fiber'].str.match(r'^\d+(\.\d+)?\s*g$').all()
print(all_grams_10) #True
# Out:
# True
# True
# False
# False
# True
# False

# %% [markdown]
# **SODIUM, SUGARS, and FIBER:**
#
# The unit check for sodium, sugars, and fibers came back False meaning that some values within that column have units that aren't 'mg' and finding if those units are omitted completely like they are in cholesterol, alcohol, and caffeine or are a different measurement is important.  Luckily the units are metric so numeric conversion is simplified.
#
# - The units for sodium were found to be mg, and nan which means luckily no numeric conversions are necessary and sodium can be folded into the next function which will deal with that problem in other columns.

# %%
# Extract the non-numeric part of each value in the 'sodium' column
units_sodium = nutrition_filtered['sodium'].str.extract(r'(\D+)$')
units_sugars = nutrition_filtered['sugars'].str.extract(r'(\D+)$')
units_fiber = nutrition_filtered['fiber'].str.extract(r'(\D+)$')
# Find the unique units
unique_units_so = units_sodium[0].unique()
unique_units_su = units_sugars[0].unique()
unique_units_fi = units_fiber[0].unique()

print(unique_units_so)
print(unique_units_su)
print(unique_units_fi)

# Checking the non-numeric part of cholesterol values because my function is 
# producing the expected results.  Checking my expectations really.

units_chol = nutrition_filtered['cholesterol'].str.extract(r'(\D+)$')
unique_chol_units = units_chol[0].unique()
print(unique_chol_units)
# Out:
# [' mg' nan]
# [' g' nan]
# [' g' nan]
# [nan 'mg']

# %% [markdown]
# **SODIUM, CHOLESTEROL, ALCOHOL, AND CAFFEINE:**
#
# These four columns have a mix of values with units and without units.  To make sure all units match we need to create a separate function that can be repeatedly called to make sure those string values found within these columns have the same units so we can strip them of those unit abbreviations.

# %%
def check_nutrition_units(value):
    if isinstance(value, str):
        return value.endswith('g') or value.endswith('mg') or value == '0'
    return value == 0  # Explicitly check for numeric 0 values

# Apply the function to the 'cholesterol' column
cholesterol_check = nutrition_filtered['cholesterol'].apply(check_nutrition_units)
sodium_check = nutrition_filtered['sodium'].apply(check_nutrition_units)
alcohol_check = nutrition_filtered['alcohol'].apply(check_nutrition_units)
caffeine_check = nutrition_filtered['caffeine'].apply(check_nutrition_units)

# Troubleshooting and testing my function to make sure the outputs are as expected
        # failing_rows = nutrition_filtered[~sodium_check]
        # print(failing_rows[['sodium']])
        # print(failing_rows['sodium'].apply(type).unique())

# Alcohol is in units 'g' so the first run produced false.  Adding a caveat for 'g' 
# and not just 'mg' in the function solved the problem.
        # failing_rows = nutrition_filtered[~alcohol_check]
        # print(failing_rows[['alcohol']])
        # print(failing_rows['alcohol'].apply(type).unique())



# Print the result
print(cholesterol_check.all())
print(sodium_check.all())
print(alcohol_check.all())
print(caffeine_check.all())
# Out:
# True
# True
# True
# True

# %% [markdown]
# **STRIPPING UNITS:**
#
# Now that we've surmised that the units are indeed uniform for our columns so long as the row value is non-zero we can carefully strip the string values off each column and check/change the datatype to numeric for future calculations.
#
# With the units being stripped off, the copied dataframe will have column names adjusted to ensure the unit information of each column remains intact.

# %%
# def strip_units(data, columns):
#     for col in columns:
#         data[col] = data[col].apply(lambda x: float(x.replace('g', '')) 
#                                     if isinstance(x, str) and x.endswith('g') else
#                                                                 float(x.replace('mg', '')) 
#                                     if isinstance(x, str) and x.endswith('mg') else
#                                                                 0.0 if x == '0' or x == 0
#                                     else x)
#     return data
import re

def strip_units(data, columns):
    for col in columns:
        def convert_value(x):
            try:
                if isinstance(x, str):
                    x = re.sub(r'[^\d.]', '', x)  # Remove any non-digit and non-decimal characters
                    return float(x) if x else float('nan')  # Convert to float, handle empty strings
                elif x == 0:
                    return 0.0
                return float(x)
            except ValueError:
                print(f"Error converting value: {x} in column: {col}")
                return float('nan')  # or handle it in another way
        data[col] = data[col].apply(convert_value)
    return data

# Copy nutrition dataset for safety
nutrition_copy = nutrition_filtered.copy()

# List of columns ready to strip.
columns_to_strip_g = ['serving_size', 'total_fat', 'sugars', 'carbohydrate', 'fiber',
                      'alcohol', 'cholesterol', 'sodium', 'caffeine', 'saturated_fat','calories']
nutrition_copy = strip_units(nutrition_copy, columns_to_strip_g)


# Dictionary of new column names with units preserved
new_columns = {
    'serving_size': 'serving_size (g)',
    'calories': 'calories (kcal)',
    'total_fat': 'total_fat (g)',
    'saturated_fat': 'saturated_fat (g)', 
    'cholesterol': 'cholesterol (mg)',
    'sodium': 'sodium (mg)', 
    'sugars': 'sugars (g)', 
    'carbohydrate': 'carbohydrate (g)', 
    'fiber': 'fiber (g)', 
    'alcohol': 'alcohol (g)', 
    'caffeine': 'caffeine (mg)'
    }

# Rename the columns
nutrition_copy.rename(columns=new_columns, inplace=True)

# Print the updated DataFrame
print(nutrition_copy.head())
# Out:
#               name  serving_size (g)  calories (kcal)  total_fat (g)  saturated_fat (g)  cholesterol (mg)  sodium (mg)  sugars (g)  carbohydrate (g)  fiber (g)  alcohol (g)  caffeine (mg)
# 0       Cornstarch             100.0            381.0            0.1                NaN               0.0          9.0        0.00             91.27        0.9          0.0            0.0
# 1     Nuts, pecans             100.0            691.0           72.0                6.2               0.0          0.0        3.97             13.86        9.6          0.0            0.0
# 2    Eggplant, raw             100.0             25.0            0.2                NaN               0.0          2.0        3.53              5.88        3.0          0.0            0.0
# 3   Teff, uncooked             100.0            367.0            2.4                0.4               0.0         12.0        1.84             73.13        8.0          0.0            0.0
# ...

# %% [markdown]
# **SATURATED FAT:**
#
# Saturated Fat, I've been avoiding it since there's no universally good way of dealing with its NaN values.  While some can easily be zeroed out--for fruits or vegetables--there are more than a few processed foods within this compiled list.
#
# Mulitple imputation appears to be a viable solution at first glance.
#
#     Pan Dulce at index 8772 was the first clue that replace NaN with zeros wouldn't suffice.  The imputer seems to get the job done with perhaps a moderate over-estimate for the saturated fat values though a quick comparison between the nutritional values of the dataset vs the USDA website find these values to be on average 38% higher.

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer


# Split the cleaned data frame into two sets of data, the first two rows which provide an index and a name
# and then rest of the data, the numeric values of nutritional information

imputer_cols = nutrition_copy.select_dtypes(include = ['float64']).columns
data_columns = nutrition_copy.select_dtypes(exclude = ['float64'])


imputer = IterativeImputer()
nutri_imputed = pd.DataFrame(imputer.fit_transform(nutrition_copy[imputer_cols]), 
                                 columns = imputer_cols)

nutri_imputed[nutri_imputed < 0] = 0
nutri_imputed = nutri_imputed.round(2)

nutrition_imputed = pd.concat([data_columns, nutri_imputed], axis=1)


print(nutrition_imputed.head())

# Checking the value imputed for Pan Dulce a Mexican Sweet Bread (similar to brioche but veritably unique)
print(nutrition_imputed.iloc[8772])
# Out:
#               name  serving_size (g)  calories (kcal)  total_fat (g)  saturated_fat (g)  cholesterol (mg)  sodium (mg)  sugars (g)  carbohydrate (g)  fiber (g)  alcohol (g)  caffeine (mg)
# 0       Cornstarch             100.0            381.0            0.1                0.0               0.0          9.0        0.00             91.27        0.9          0.0            0.0
# 1     Nuts, pecans             100.0            691.0           72.0                6.2               0.0          0.0        3.97             13.86        9.6          0.0            0.0
# 2    Eggplant, raw             100.0             25.0            0.2                0.1               0.0          2.0        3.53              5.88        3.0          0.0            0.0
# 3   Teff, uncooked             100.0            367.0            2.4                0.4               0.0         12.0        1.84             73.13        8.0          0.0            0.0
# ...

# %% [markdown]
# **CONCLUSION:**
#
# Looking back on this data it's clear that the 'name' column needs to be cleaned up.  While superfluous words can be truncated doing it indiscriminately can lead to unforeseen consequences.  This dataset is limited in that way.  Perhaps there is a tidier dataset from a government agency like the USDA.
#
# A quick search into USDA provided data seems to be promising though thorough in the details it provides.  Finding a through line to combine the files provided by the USDA and combing through it to find the data important to nutrition information and not the agricultural and economic information may prove to be a fuller option for this kind of analysis.
